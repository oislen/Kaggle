# %%
import pandas as pd
import numpy as np
import cons
import value_analysis as va

# %%
# load in data
base = pd.read_csv(cons.base_data_fpath, sep = '|')

# redefine some of the numeric variables into categories
base['cat_survived'] = base['Survived'].map({1.0:'yes', 0.0:'no'})
base['cat_pclass'] = base['Pclass'].astype(str)
base['cat_sibsp'] = base['SibSp'].astype(str)
base['cat_parch'] = base['Parch'].astype(str)
base['cat_famsize'] = base['FamSize'].astype(str)
base['cat_alone'] = base['Alone'].astype(str)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Descriptive Stats

# %%
va.Desc.stats(dataset = base, 
              attrs = base.columns, 
              stats_type = "numeric",
              print_statements = False
              )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\scipy\stats\stats.py:402: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(np.array(a, dtype=dtype))
#              size  count         sum     mean  geo_mean   median  mode_1  \
# PassengerId  1309   1309  857395.000  655.000   483.215  655.000    1.00
# Survived     1309    891     342.000    0.384     0.000    0.000    0.00
# Pclass       1309   1309    3004.000    2.295     2.100    3.000    3.00
# Age          1309   1046   31255.670   29.881    24.718   28.000   24.00
# SibSp        1309   1309     653.000    0.499     0.000    0.000    0.00
# Parch        1309   1309     504.000    0.385     0.000    0.000    0.00
# Fare         1309   1308   43550.487   33.295     0.000   14.454    8.05
# FamSize      1309   1309    1157.000    0.884     0.000    0.000    0.00
# Alone        1309   1309     790.000    0.604     0.000    1.000    1.00
#
#              mode_1_cnt  mode_1_prct  mode_2  ...  nan_perc  nunique  minimum  \
# PassengerId           1        0.076   861.0  ...     0.000     1309     1.00
# Survived            549       41.940     1.0  ...    31.933        2     0.00
# Pclass              709       54.163     1.0  ...     0.000        3     1.00
# Age                  47        3.591    22.0  ...    20.092       98     0.17
# SibSp               891       68.067     1.0  ...     0.000        7     0.00
# Parch              1002       76.547     1.0  ...     0.000        8     0.00
# Fare                 60        4.584    13.0  ...     0.076      281     0.00
# FamSize             790       60.351     1.0  ...     0.000        9     0.00
# Alone               790       60.351     0.0  ...     0.000        2     0.00
#
#               maximum     range  quartile_1  quartile_3      iqr   skew  \
# PassengerId  1309.000  1308.000     328.000     982.000  654.000  0.000
# Survived        1.000     1.000       0.000       1.000    1.000  0.478
# Pclass          3.000     2.000       2.000       3.000    1.000 -0.598
# Age            80.000    79.830      21.000      39.000   18.000  0.407
# SibSp           8.000     8.000       0.000       1.000    1.000  3.840
# Parch           9.000     9.000       0.000       0.000    0.000  3.665
# Fare          512.329   512.329       7.896      31.275   23.379  4.363
# FamSize        10.000    10.000       0.000       1.000    1.000  2.850
# Alone           1.000     1.000       0.000       1.000    1.000 -0.423
#
#              kurtosis
# PassengerId    -1.200
# Survived       -1.772
# Pclass         -1.315
# Age             0.141
# SibSp          19.962
# Parch          21.454
# Fare           26.920
# FamSize        10.255
# Alone          -1.821
#
# [9 rows x 31 columns]

# %%
va.Desc.stats(dataset = base, 
              attrs = base.columns, 
              stats_type = "string",
              print_statements = False
              )
# Out:
#               size  count  num_modes              1st mode  1st mode Cnt  \
# Name          1309   1309       1307  Connolly, Miss. Kate             2
# Sex           1309   1309          2                  male           843
# Ticket        1309   1309        929              CA. 2343            11
# Cabin         1309    295        186           C23 C25 C27             6
# Embarked      1309   1307          3                     S           914
# Dataset       1309   1309          2                 train           891
# cat_survived  1309    891          2                    no           549
# cat_pclass    1309   1309          3                     3           709
# cat_sibsp     1309   1309          7                     0           891
# cat_parch     1309   1309          8                     0          1002
# cat_famsize   1309   1309          9                     0           790
# cat_alone     1309   1309          2                     1           790
#
#               1st mode %          2nd mode  2nd mode Cnt  2nd mode %  \
# Name               0.153  Kelly, Mr. James             2       0.153
# Sex               64.400            female           466      35.600
# Ticket             0.840              1601             8       0.611
# Cabin              0.458                G6             5       0.382
# Embarked          69.824                 C           270      20.626
# Dataset           68.067              test           418      31.933
# cat_survived      41.940               yes           342      26.127
# cat_pclass        54.163                 1           323      24.675
# cat_sibsp         68.067                 1           319      24.370
# cat_parch         76.547                 1           170      12.987
# cat_famsize       60.351                 1           235      17.953
# cat_alone         60.351                 0           519      39.649
#
#                                            3rd mode  3rd mode Cnt  3rd mode %  \
# Name          Baclini, Mrs. Solomon (Latifa Qurban)           1.0       0.076
# Sex                                             NaN           NaN         NaN
# Ticket                                      CA 2144           8.0       0.611
# Cabin                               B57 B59 B63 B66           5.0       0.382
# Embarked                                          Q         123.0       9.396
# Dataset                                         NaN           NaN         NaN
# cat_survived                                    NaN           NaN         NaN
# cat_pclass                                        2         277.0      21.161
# cat_sibsp                                         2          42.0       3.209
# cat_parch                                         2         113.0       8.633
# cat_famsize                                       2         159.0      12.147
# cat_alone                                       NaN           NaN         NaN
#
#                                        4th mode  4th mode Cnt  4th mode %  \
# Name          Mellinger, Miss. Madeleine Violet           1.0       0.076
# Sex                                         NaN           NaN         NaN
# Ticket                                 PC 17608           7.0       0.535
# Cabin                                        F2           4.0       0.306
# Embarked                                    NaN           NaN         NaN
# Dataset                                     NaN           NaN         NaN
# cat_survived                                NaN           NaN         NaN
# cat_pclass                                  NaN           NaN         NaN
# cat_sibsp                                     4          22.0       1.681
# cat_parch                                     3           8.0       0.611
# cat_famsize                                   3          43.0       3.285
# cat_alone                                   NaN           NaN         NaN
#
#               max str len  min str len  range str len  nan Cnt   nan %
# Name                 82.0         12.0           70.0        0   0.000
# Sex                   6.0          4.0            2.0        0   0.000
# Ticket               18.0          3.0           15.0        0   0.000
# Cabin                15.0          1.0           14.0     1014  77.464
# Embarked              1.0          1.0            0.0        2   0.153
# Dataset               5.0          4.0            1.0        0   0.000
# cat_survived          3.0          2.0            1.0      418  31.933
# cat_pclass            1.0          1.0            0.0        0   0.000
# cat_sibsp             1.0          1.0            0.0        0   0.000
# cat_parch             1.0          1.0            0.0        0   0.000
# cat_famsize           2.0          1.0            1.0        0   0.000
# cat_alone             1.0          1.0            0.0        0   0.000

# %% [markdown]
# ### Visualisations

# %%
va.Vis.hist(dataset = base,
            num_var = ['Age'],
            bins = None,
            hist = True,
            kde = False
            )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
va.Vis.hist(dataset = base,
            num_var = ['Fare'],
            bins = None,
            hist = True,
            kde = False
            )

# %%
va.Vis.hist(dataset = base,
            num_var = ['FamSize'],
            bins = None,
            hist = True,
            kde = False
            )

# %%
va.Vis.hist(dataset = base,
            num_var = ['Parch'],
            bins = None,
            hist = True,
            kde = False
            )

# %%
va.Vis.hist(dataset = base,
            num_var = ['SibSp'],
            bins = None,
            hist = True,
            kde = False
            )

# %%
va.Vis.hist(dataset = base,
            num_var = ['Pclass'],
            bins = None,
            hist = True,
            kde = False
            )

# %%
va.Vis.count(dataset = base,
             cat_var = ['cat_survived']
             )

# %%
va.Vis.count(dataset = base,
             cat_var = ['Sex']
             )

# %%
va.Vis.count(dataset = base,
             cat_var = ['cat_alone']
             )

# %%
va.Vis.count(dataset = base,
             cat_var = ['Embarked']
             )

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### Association Tests

# %%
va.Desc.assoc(dataset = base,
              attrs = ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'],
              response = None,
              assoc_type = 'nominal',
              output_dir = cons.bivar_assoc_dir
              )
# Out:
#                    Statistic  df  P-value
# Xi       Xj
# Survived Pclass      102.889   2    0.000
#          Sex         263.051   1    0.000
#          SibSp        34.957   6    0.000
#          Parch        26.223   6    0.000
#          Embarked     26.489   2    0.000
# Pclass   Sex          20.379   2    0.000
#          SibSp        65.682  12    0.000
#          Parch        11.295  14    0.663
#          Embarked    205.791   4    0.000
# Sex      SibSp        51.751   6    0.000
#          Parch        79.830   7    0.000
#          Embarked     19.584   2    0.000
# SibSp    Parch       446.322  42    0.000
#          Embarked     38.521  12    0.000
# Parch    Embarked     31.800  14    0.004

# %% [markdown]
# ### Correlation Tests

# %%
va.Desc.corr(dataset = base,
             attrs = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],
             response = None,
             corr_type = 'spearman',
             output_dir = cons.bivar_corr_dir
             )
# Out:
#               Correlation  P-value
# Xi     Xj
# Pclass Age         -0.396    0.000
#        SibSp       -0.067    0.016
#        Parch       -0.029    0.299
#        Fare        -0.709    0.000
# Age    SibSp       -0.130    0.000
#        Parch       -0.216    0.000
#        Fare         0.193    0.000
# SibSp  Parch        0.438    0.000
#        Fare         0.446    0.000
# Parch  Fare         0.400    0.000

# %%
va.Desc.corr(dataset = base,
             attrs = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],
             response = None,
             corr_type = 'kendall',
             output_dir = cons.bivar_corr_dir
             )
# Out:
#               Correlation  P-value
# Xi     Xj
# Pclass Age         -0.313    0.000
#        SibSp       -0.062    0.016
#        Parch       -0.026    0.299
#        Fare        -0.592    0.000
# Age    SibSp       -0.100    0.000
#        Parch       -0.172    0.000
#        Fare         0.132    0.000
# SibSp  Parch        0.415    0.000
#        Fare         0.357    0.000
# Parch  Fare         0.323    0.000

# %%
va.Desc.corr(dataset = base,
             attrs = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],
             response = None,
             corr_type = 'goodmans_g',
             output_dir = cons.bivar_corr_dir
             )
# Out:
#               Concordant Pairs  Discordants Pairs  Goodmans Gamma  Test Stat  \
# Xi     Xj
# Pclass Age                 175                343       -0.324324  -0.215679
#        SibSp               176                222       -0.115578  -0.064160
#        Parch               158                167       -0.027692  -0.013804
#        Fare                 90                707       -0.774153  -0.954297
# Age    SibSp               189                221       -0.078049  -0.043814
#        Parch               119                214       -0.285285  -0.150129
#        Fare                445                347        0.123737   0.096994
# SibSp  Parch               294                 51        0.704348   0.509398
#        Fare                473                161        0.492114   0.393420
# Parch  Fare                367                135        0.462151   0.322731
#
#                Z-score   P-value
# Xi     Xj
# Pclass Age    0.414619  0.585381
#        SibSp  0.474421  0.525579
#        Parch  0.494493  0.505507
#        Fare   0.169967  0.830033
# Age    SibSp  0.482526  0.517474
#        Parch  0.440331  0.559669
#        Fare   0.538634  0.461366
# SibSp  Parch  0.694763  0.305237
#        Fare   0.652995  0.347005
# Parch  Fare   0.626550  0.373450

# %%
va.Desc.corr(dataset = base,
             attrs = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],
             response = None,
             corr_type = 'somers_d',
             output_dir = cons.bivar_corr_dir
             )
# Out:
#               Somers Delts
# Xi     Xj
# Pclass Age       -0.312672
#        SibSp     -0.061628
#        Parch     -0.026480
#        Fare      -0.591579
# Age    SibSp     -0.100050
#        Parch     -0.171702
#        Fare       0.131694
# SibSp  Parch      0.415068
#        Fare       0.356791
# Parch  Fare       0.322767

# %% [markdown]
# ### Visulisations

# %%
va.Vis.swarmplot(dataset = base,
                 num_var = ['Age'],
                 cat_var = ['cat_survived']
                 )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
va.Vis.swarmplot(dataset = base,
                 num_var = ['Fare'],
                 cat_var = ['cat_survived']
                 )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
va.Vis.swarmplot(dataset = base,
                 num_var = ['FamSize'],
                 cat_var = ['cat_survived']
                 )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 75.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
va.Vis.swarmplot(dataset = base,
                 num_var = ['Parch'],
                 cat_var = ['cat_survived']
                 )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 76.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
va.Vis.swarmplot(dataset = base,
                 num_var = ['SibSp'],
                 cat_var = ['cat_survived']
                 )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 81.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 79.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
va.Vis.boxplot(dataset = base,
               num_var = ['Age'],
               cat_var = ['cat_survived']
               )

# %%
va.Vis.boxplot(dataset = base,
               num_var = ['Fare'],
               cat_var = ['cat_survived']
               )

# %%
va.Vis.boxplot(dataset = base,
               num_var = ['FamSize'],
               cat_var = ['cat_survived']
               )

# %%
va.Vis.boxplot(dataset = base,
               num_var = ['Parch'],
               cat_var = ['cat_survived']
               )

# %%
va.Vis.boxplot(dataset = base,
               num_var = ['SibSp'],
               cat_var = ['cat_survived']
               )

# %%
va.Vis.violin(dataset = base,
              num_var = ['Age'],
              cat_var = ['cat_survived']
              )

# %%
va.Vis.violin(dataset = base,
              num_var = ['Fare'],
              cat_var = ['cat_survived']
              )

# %%
va.Vis.violin(dataset = base,
              num_var = ['FamSize'],
              cat_var = ['cat_survived']
              )

# %%
va.Vis.violin(dataset = base,
              num_var = ['Parch'],
              cat_var = ['cat_survived']
              )

# %%
va.Vis.violin(dataset = base,
              num_var = ['SibSp'],
              cat_var = ['cat_survived']
              )

# %%
va.Vis.count(dataset = base,
             cat_var = ['cat_pclass'],
             hue_var = ['cat_survived']
             )

# %%
va.Vis.count(dataset = base,
             cat_var = ['Sex'],
             hue_var = ['cat_survived']
             )

# %%
va.Vis.count(dataset = base,
             cat_var = ['Embarked'],
             hue_var = ['cat_survived']
             )

# %%
va.MeasureGains.analysis(dataset = base,
                 attr = 'Age',
                 target = 'Survived',
                 bin_split = 'equal_width',
                 n_bins = 4,
                 title = 'Survival Rates by Age'
                 )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# Warning: Low number of claims within bin segments.
# (<Figure size 864x576 with 1 Axes>,
#     bin_id         bins     lb     ub  survived count  survived prop  \
#  0       1   0.17:20.13   0.17  20.13            82.0           0.33
#  1       2  20.13:40.08  20.13  40.08           153.0           0.27
#  2       3  40.08:60.04  40.08  60.04            50.0           0.26
#  3       4  60.04:80.08  60.04  80.08             5.0           0.15
#
#     num_records  record %  bin_rel  bin_rel_temp
#  0          248     18.95     1.26          0.26
#  1          571     43.62     1.03          0.03
#  2          194     14.82     1.00          0.00
#  3           33      2.52     0.57         -0.43  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0                True               4     0.57        1.26           0.45
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        0.23                           14.33
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  4                               0  )

# %%
va.MeasureGains.analysis(dataset = base,
                         attr = 'Pclass',
                         target = 'Survived',
                         bin_split = 'value',
                         title = 'Survival Rates by Class'
                         )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# Warning: Low number of claims within bin segments.
# (<Figure size 864x576 with 1 Axes>,
#     bin_id  bins   lb   ub  survived count  survived prop  num_records  \
#  0       1  1.0   1.0  1.0           136.0           0.42          323
#  1       2  2.0   2.0  2.0            87.0           0.31          277
#  2       3  3.0   3.0  3.0           119.0           0.17          709
#
#     record %  bin_rel  bin_rel_temp
#  0     24.68     1.61          0.61
#  1     21.16     1.19          0.19
#  2     54.16     0.65         -0.35  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0                True               3     0.65        1.61            0.4
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        0.48                           13.88
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  3                               0  )

# %%
va.MeasureGains.analysis(dataset = base,
                         attr = 'SibSp',
                         target = 'Survived',
                         bin_split = 'value',
                         title = 'Survival Rates by SibSp'
                         )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# Warning: Low number of claims within bin segments.
# (<Figure size 864x576 with 1 Axes>,
#     bin_id  bins   lb   ub  survived count  survived prop  num_records  \
#  0       1  0.0   0.0  0.0           210.0           0.24          891
#  1       2  1.0   1.0  1.0           112.0           0.35          319
#  2       3  2.0   2.0  2.0            13.0           0.31           42
#  3       4  3.0   3.0  3.0             4.0           0.20           20
#  4       5  4.0   4.0  4.0             3.0           0.14           22
#  5       6  5.0   5.0  5.0             0.0           0.00            6
#  6       7  8.0   8.0  8.0             0.0           0.00            9
#
#     record %  bin_rel  bin_rel_temp
#  0     68.07     0.92         -0.08
#  1     24.37     1.34          0.34
#  2      3.21     1.19          0.19
#  3      1.53     0.77         -0.23
#  4      1.68     0.54         -0.46
#  5      0.46     0.00         -1.00
#  6      0.69     0.00         -1.00  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0               False               7      0.0        0.92            0.0
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        0.29                           18.25
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  5                               0  )

# %%
va.MeasureGains.analysis(dataset = base,
                         attr = 'Parch',
                         target = 'Survived',
                         bin_split = 'value',
                         title = 'Survival Rates by Parch'
                         )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# Warning: Low number of claims within bin segments.
# (<Figure size 864x576 with 1 Axes>,
#     bin_id  bins   lb   ub  survived count  survived prop  num_records  \
#  0       1  0.0   0.0  0.0           233.0           0.23         1002
#  1       2  1.0   1.0  1.0            65.0           0.38          170
#  2       3  2.0   2.0  2.0            40.0           0.35          113
#  3       4  3.0   3.0  3.0             3.0           0.38            8
#  4       5  4.0   4.0  4.0             0.0           0.00            6
#  5       6  5.0   5.0  5.0             1.0           0.17            6
#  6       7  6.0   6.0  6.0             0.0           0.00            2
#  7       8  9.0   9.0  9.0             0.0           0.00            2
#
#     record %  bin_rel  bin_rel_temp
#  0     76.55     0.88         -0.12
#  1     12.99     1.45          0.45
#  2      8.63     1.34          0.34
#  3      0.61     1.45          0.45
#  4      0.46     0.00         -1.00
#  5      0.46     0.65         -0.35
#  6      0.15     0.00         -1.00
#  7      0.15     0.00         -1.00  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0               False               8      0.0        0.88            0.0
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        0.51                           16.13
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  5                               0  )

# %%
va.MeasureGains.analysis(dataset = base,
                         attr = 'Age',
                         target = 'Fare',
                         bin_split = 'equal_size',
                         n_bins = 5,
                         title = 'Fare Rates by Age'
                         )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# Warning: Low number of claims within bin segments.
# (<Figure size 864x576 with 1 Axes>,
#     bin_id       bins     lb    ub  fare mean  num_records  record %  bin_rel  \
#  0       1  0.17:19.0   0.17  19.0  30.837371          225     17.19     0.93
#  1       2  19.0:25.0  19.00  25.0  25.854740          218     16.65     0.78
#  2       3  25.0:31.0  25.00  31.0  29.657743          191     14.59     0.89
#  3       4  31.0:42.0  31.00  42.0  41.963440          217     16.58     1.26
#  4       5  42.0:80.0  42.00  80.0  56.657304          195     14.90     1.70
#
#     bin_rel_temp
#  0         -0.07
#  1         -0.22
#  2         -0.11
#  3          0.26
#  4          0.70  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0               False               5      1.7        0.93           1.83
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        0.27                            4.02
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  0                               5  )

# %%
va.MeasureGains.analysis(dataset = base,
                         attr = 'Pclass',
                         target = 'Fare',
                         bin_split = 'value',
                         title = 'Fare Rates by Class'
                         )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# Warning: Low number of claims within bin segments.
# (<Figure size 864x576 with 1 Axes>,
#     bin_id  bins   lb   ub  fare mean  num_records  record %  bin_rel  \
#  0       1  1.0   1.0  1.0  87.508992          323     24.68     2.63
#  1       2  2.0   2.0  2.0  21.179196          277     21.16     0.64
#  2       3  3.0   3.0  3.0  13.302889          709     54.16     0.40
#
#     bin_rel_temp
#  0          1.63
#  1         -0.36
#  2         -0.60  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0                True               3      0.4        2.63           0.15
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        1.11                           13.88
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  3                               0  )

# %%
va.MeasureGains.analysis(dataset = base,
                         attr = 'Pclass',
                         target = 'Age',
                         bin_split = 'value',
                         title = 'Age Relativity by Class'
                         )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# Warning: Low number of claims within bin segments.
# (<Figure size 864x576 with 1 Axes>,
#     bin_id  bins   lb   ub   age mean  num_records  record %  bin_rel  \
#  0       1  1.0   1.0  1.0  39.159930          323     24.68     1.31
#  1       2  2.0   2.0  2.0  29.506705          277     21.16     0.99
#  2       3  3.0   3.0  3.0  24.816367          709     54.16     0.83
#
#     bin_rel_temp
#  0          0.31
#  1         -0.01
#  2         -0.17  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0                True               3     0.83        1.31           0.63
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        0.24                           13.88
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  3                               0  )

# %%
va.MeasureGains.analysis(dataset = base,
                         attr = 'SibSp',
                         target = 'Age',
                         bin_split = 'value',
                         title = 'Age Relativity by SibSp'
                         )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# Warning: Low number of claims within bin segments.
# (<Figure size 864x576 with 1 Axes>,
#     bin_id  bins   lb   ub   age mean  num_records  record %  bin_rel  \
#  0       1  0.0   0.0  0.0  30.921766          891     68.07     1.03
#  1       2  1.0   1.0  1.0  31.058071          319     24.37     1.04
#  2       3  2.0   2.0  2.0  23.569444           42      3.21     0.79
#  3       4  3.0   3.0  3.0  16.312500           20      1.53     0.55
#  4       5  4.0   4.0  4.0   8.772727           22      1.68     0.29
#  5       6  5.0   5.0  5.0  10.166667            6      0.46     0.34
#  6       7  8.0   8.0  8.0  14.500000            9      0.69     0.49
#
#     bin_rel_temp
#  0          0.03
#  1          0.04
#  2         -0.21
#  3         -0.45
#  4         -0.71
#  5         -0.66
#  6         -0.51  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0               False               7     0.49        1.03           0.48
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        0.16                           18.25
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  5                               2  )

# %%
va.MeasureGains.analysis(dataset = base,
                         attr = 'Parch',
                         target = 'Age',
                         bin_split = 'value',
                         title = 'Age Relativity by Parch'
                         )
# Out:
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:863: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bins'] = data['bins'].str.replace(pat = '(^nan$)',
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:257: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ')', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:258: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '(', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:259: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = ']', repl = '')
# C:\Users\User\Documents\GitHub\value_analysis\value_analysis\MeasureGains.py:260: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   group[attr] = group[attr].str.replace(pat = '[', repl = '')
# posx and posy should be finite values
# Warning: Low number of claims within bin segments.
# posx and posy should be finite values
# (<Figure size 864x576 with 1 Axes>,
#     bin_id  bins   lb   ub   age mean  num_records  record %  bin_rel  \
#  0       1  0.0   0.0  0.0  31.969401         1002     76.55     1.07
#  1       2  1.0   1.0  1.0  24.965625          170     12.99     0.84
#  2       3  2.0   2.0  2.0  18.975979          113      8.63     0.64
#  3       4  3.0   3.0  3.0  38.875000            8      0.61     1.30
#  4       5  4.0   4.0  4.0  47.600000            6      0.46     1.59
#  5       6  5.0   5.0  5.0  39.333333            6      0.46     1.32
#  6       7  6.0   6.0  6.0  41.500000            2      0.15     1.39
#  7       8  9.0   9.0  9.0        NaN            2      0.15      NaN
#
#     bin_rel_temp
#  0          0.07
#  1         -0.16
#  2         -0.36
#  3          0.30
#  4          0.59
#  5          0.32
#  6          0.39
#  7           NaN  ,
#     Strictly Monotonic  Number of Bins  Top Bin  Bottom Bin  Top to Bottom  \
#  0               False               8      NaN        1.07            NaN
#
#     Mean Bin Height Difference  Mean Exposure Spread Deviation  \
#  0                        0.25                           16.13
#
#     N Bins Greater than Top to Bottom  N Bins Less than Top to Bottom
#  0                                  0                               0  )

# %% [markdown]
# # Trivariate Analysis

# %%
va.Vis.scatter(dataset = base, 
               res_var = ['Fare'],
               pred_var = ['Age'],
               hue_var = ['cat_survived']
               )

# %%
va.Vis.swarmplot(dataset = base,
                 num_var = ['Fare'],
                 cat_var = ['cat_pclass'],
                 hue_var = ['cat_survived']
                 )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
va.Vis.boxplot(dataset = base,
               num_var = ['FamSize'],
               cat_var = ['cat_survived'],
               hue_var = ['Sex']
               )

# %%
va.Vis.boxplot(dataset = base,
               num_var = ['Age'],
               cat_var = ['cat_survived'],
               hue_var = ['Sex']
               )

# %%
va.Vis.swarmplot(dataset = base,
                 num_var = ['Age'],
                 cat_var = ['cat_survived'],
                 hue_var = ['Sex']
                 )
# Out:
# C:\Users\User\Anaconda3\envs\analytics\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
va.Vis.stripplot(dataset = base,
                 num_var = ['Age'],
                 cat_var = ['cat_survived'],
                 hue_var = ['Sex']
                 )

# %%
va.Vis.pointplot(dataset = base,
                 num_var = ['Age'],
                 cat_var = ['cat_survived'],
                 hue_var = ['Sex'],
                 estimator = np.mean
                 )

# %%
va.Vis.violin(dataset = base,
              num_var = ['Age'],
              cat_var = ['cat_survived'],
              hue_var = ['cat_pclass'],
              split = False
              )
